# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1><br><div class="toc"><ul class="toc-item"><li><span><a data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><ul class="toc-item"><li><span><a data-toc-modified-id="Описание-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a data-toc-modified-id="Цель-работы-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Цель работы</a></span></li></ul></li><li><span><a data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Чтение и предобработка данных</a></span></li><li><span><a data-toc-modified-id="Исследовательский-анализ-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-количества-детей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследование количественного признака 'credit_score'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-семейного-положения-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Исследование количественного признака 'age'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-о-уровня-дохода-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование количественного признака 'tenure'</a></span></li><li><span><a data-toc-modified-id="Влияние-целей-кредита-на-его-возврат-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Исследование количественного признака 'balance'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-возраста-заемщика-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Исследование количественного признака 'num_of_products'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-возраста-заемщика-3.5"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Исследование количественного признака 'has_cr_card'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-возраста-заемщика-3.5"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Исследование количественного признака 'estimated_salary'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-возраста-заемщика-3.5"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Исследование количественного признака 'estimated_salary'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-возраста-заемщика-3.5"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Исследование целевого признака 'exited'</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-возраста-заемщика-3.5"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Коррелляция количественных признаков</a></span></li></ul><li><span><a data-toc-modified-id="Исследовательский-анализ-3"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-количества-детей-3.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Разбиение датасета на 3 набора: Train, Valid, Test (OHE, OE, Manual)</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-от-семейного-положения-3.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Выбор модели обучения</a></span></li><li><span><a data-toc-modified-id="Зависимость-возврата-кредита-о-уровня-дохода-3.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Сравнение моделей обучения и проверка на адекватность</a></span></li></ul><li><span><a data-toc-modified-id="Исследовательский-анализ-3"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование модели и исследование важности признаков</a></span><ul class="toc-item"></ul><li><span><a data-toc-modified-id="Общий-вывод-4"><span class="toc-item-num">6&nbsp;&nbsp;</span>Отчет по проекту</a></span></ul></div>

# %% [markdown]
# ## Прогнозирование оттока клиентов банка
#
# Исследование влияния поведения клиентов банка на прогнозируемый отток.

# %% [markdown]
# ## 1. Описание проекта

# %% [markdown]
# Из банка стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых. Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Нам были предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.

# %% [markdown]
# ###  1.1. Структура данных

# %% [markdown]
# Данные сохранены в датасет data и имеют следующую структуру:<br>
#
# *Признаки*
#  - RowNumber — индекс строки в данных;
#  - CustomerId — уникальный идентификатор клиента;
#  - Surname — фамилия;
#  - CreditScore — кредитный рейтинг;
#  - Geography — страна проживания;
#  - Gender — пол;
#  - Age — возраст;
#  - Tenure — сколько лет человек является клиентом банка;
#  - Balance — баланс на счёте;
#  - NumOfProducts — количество продуктов банка, используемых клиентом;
#  - HasCrCard — наличие кредитной карты;
#  - IsActiveMember — активность клиента;
#  - EstimatedSalary — предполагаемая зарплата.
#
# *Целевой признак*
#  - Exited — факт ухода клиента.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ### 1.2. Цель работы

# %% [markdown]
# Необходимо построить модель с предельно большим значением *F1*-меры. Чтобы прогнозные данные были максимально качественные  метрику необходимо довести до 0.59. Проверить *F1*-меру необходимо на тестовой выборке.
#
# Дополнительно необходимо измерить метрику *AUC-ROC* и сравнить её значение с *F1*-мерой.

# %% [markdown]
#  План работы:
#
#  - Загрузить и подготовить данные;<br>
#  - Обработать аномалии и пропуски;<br>
#  - Исследовать данные и баланс классов;<br>
#  - Обучить модели без учёта дисбаланса целевого признака;<br>
#  - Улучшить качество моделей, учитывая дисбаланс классов и методы кодировки категориальных признаков;<br>
#  - Обучить разные модели тремя методами категоризации признаков и найти наилучшую;<br>
#  - Провести финальное тестирование и исследовать важность признаков;<br>
#  - Довести до заказчика результаты исследования и представить модель прогнозирования оттока клиентов. <br>

# %% [markdown]
# ## 2. Чтение и предобработка данных

# %%
#!pip install imblearn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import re
import time

from sklearn.compose import make_column_transformer
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.dummy import DummyRegressor

from sklearn.linear_model import (
    Ridge,
    LogisticRegression
)

from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import shuffle
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import (
    train_test_split, 
    GridSearchCV, 
    RandomizedSearchCV,
    cross_val_score,
    KFold
    )
from sklearn.metrics import (
    r2_score, 
    confusion_matrix, 
    recall_score, 
    precision_score, 
    precision_recall_curve,
    f1_score, 
    roc_auc_score, 
    roc_curve,
    mean_absolute_error,
    PredictionErrorDisplay,
    RocCurveDisplay
    )

#from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler
)

from imblearn.pipeline import make_pipeline
from imblearn import datasets

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# настройки
warnings.filterwarnings("ignore")

# константы заглавными буквами
RANDOM_STATE = 12345

# %%
import nltk
import sklearn
print('The nltk version is {}.'.format(nltk.__version__))
print('The scikit-learn version is {}.'.format(sklearn.__version__))
print('The Phyton version is {}.'.format(pd.__version__))
# Out:
# The nltk version is 3.8.1.
# The scikit-learn version is 1.3.0.
# The Phyton version is 1.4.4.

# %%
# Фиксация стартового времени начала проекта
start_all = time.time()

# %%
# чтение файла
try:
    df = pd.read_csv('/datasets/Churn.csv')
except:
    df = pd.read_csv('C:/Users/1/Documents/Sprint_10/datasets/Churn.csv')

# %%
# Функция чтения датасета
def get_data_info(data):
    display(data.sample(5))
    display(data.info())

# %%
get_data_info(df)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 5206       5207    15632826    Tardent          493    France    Male   38
# 6567       6568    15593425  Bracewell          662     Spain  Female   54
# 2764       2765    15597265        Mao          660    France    Male   38
# 9900       9901    15645896     Duncan          646   Germany    Male   39
# 9447       9448    15810390      Amadi          718    France  Female   41
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5206     3.0  134006.77              1          1               0
# 6567     1.0  187997.15              1          0               0
# 2764     7.0       0.00              2          0               1
# 9900     6.0  121681.91              2          0               1
# 9447     1.0       0.00              2          0               1
#
#       EstimatedSalary  Exited
# 5206         89578.32       0
# 6567        111442.71       1
# ...

# %% [markdown]
#  Сразу же удалим из датасета не несущие ценности для дальнейшего исследования столбцы 'RowNumber', 'Surname', 'CustomerId'.*

# %%
df = df.drop(columns=['RowNumber', 'Surname', 'CustomerId'])

# %%
# Переименование столбцов к регистру Snake case
df.columns = [re.sub(r'(?<!^)(?=[A-Z])', '_', i).lower() for i in df.columns]

# %% [markdown]
# Проверка пропущенных данных в датасете

# %%
# Функция вычисления пропущенных значений в колонках датасета
def missing_values_table(df):
        # Общее количество пропусков
        mis_val = df.isnull().sum()
        
        # Доля пропущенных значений
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Создание таблицы с результатами
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Переименование колонок
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Пропуски', 1 : 'Доля, %'})
        
        # Сортировка значений по доле пропусков
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        'Доля, %', ascending=False).round(1)
        
        # Печать общей информации
        print ("Выбранный датафрейм имеет " + str(df.shape[1]) + " столбцов.\n"      
            "Из них " + str(mis_val_table_ren_columns.shape[0]) +
              " столбца имеют пропуски значений.")
        
        # Return
        return mis_val_table_ren_columns

# %%
missing_values_table(df)
# Out:
# Выбранный датафрейм имеет 11 столбцов.
# Из них 1 столбца имеют пропуски значений.
#         Пропуски  Доля, %
# tenure       909      9.1

# %% [markdown]
# Присутствуют пустые значения по полю 'tenure'. Признак 'tenure' содержит сведения о том, сколько лет человек является клиентом банка. Поэтому пустые значения в 'tenure' целесообразно заполнить их медианным значением.

# %%
df['tenure'] = df['tenure'].fillna(df['tenure'].median()).astype('int64')

# %% [markdown]
# Заполнение пропусков медианным значением — это лучшее решение для количественных переменных, потому что медиана  —  это такое число в выборке, когда ровно половина элементов больше него, а другая половина —  меньше. В объеме данных в столбце могут содержаться цифры различного характера. Но когда эти цифры характеризуют несколько категорий показателей, то применять среднее арифметическое к набору данных будет неуместно и неверно. Среднее значение, или любые другие будут некорректно характеризовать данные, когда некоторые значения сильно выделяются среди большинства.

# %%
missing_values_table(df)
# Out:
# Выбранный датафрейм имеет 11 столбцов.
# Из них 0 столбца имеют пропуски значений.
# Empty DataFrame
# Columns: [Пропуски, Доля, %]
# Index: []

# %% [markdown]
# Убедимся в отсутствии явных дубликатов в таблице df

# %%
df.duplicated().sum()
# Out:
# 0

# %%
get_data_info(df)
# Out:
#       credit_score geography  gender  age  tenure    balance  num_of_products  \
# 8106           590     Spain  Female   51       5   84474.62                2
# 5824           636     Spain    Male   36       1       0.00                3
# 2993           745     Spain  Female   59       8       0.00                1
# 9265           675    France  Female   38       1  104016.88                1
# 3767           769    France    Male   29       4  145471.37                1
#
#       has_cr_card  is_active_member  estimated_salary  exited
# 8106            1                 1         190937.09       0
# 5824            1                 1          74048.10       1
# 2993            1                 1          36124.98       0
# 9265            0                 0          22068.83       1
# 3767            1                 0         188382.77       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
# ...

# %% [markdown]
# Исследуем характер разброса численных данных по столбцам датасета.

# %%
for col in df.columns:
    col_name = 'Распределение данных ' + col
    if df[col].dtype != 'object':
        plt.figure(figsize=(8, 2))
        sns.boxplot(x=col, data=df, color='green').set(title=col_name)
        plt.show()
        display(df[col].describe())
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: credit_score, dtype: float64
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: age, dtype: float64
# count    10000.00000
# mean         4.99790
# std          2.76001
# min          0.00000
# 25%          3.00000
# 50%          5.00000
# 75%          7.00000
# max         10.00000
# Name: tenure, dtype: float64
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: balance, dtype: float64
# count    10000.000000
# mean         1.530200
# std          0.581654
# min          1.000000
# ...

# %% [markdown]
# Анализ характерного разброса данных показал, что медианные значения практически во всех параметрах близки к средним. А вот стандартное отклонение, характеризующее разброс величин, показало некоторое отличие от среднего арифметического. Значения неоднородны и возможны некоторые аномалии или выбросы.

# %% [markdown]
# <div style="border:solid gray 3px; padding: 20px">
# <b> </b>
#
# **Вывод по разделу 2. Предобработка данных.**
#
# Таблица состоит из 9 количественных столбцов и 2 категориальных столбцов (geography, gender).
# Таблица не содержит дубликатов, пустых значений, наименования столбцов правильные.
#
# Приступаем  к исследованию признаков.

# %% [markdown]
# ## 3. Исследовательский анализ

# %% [markdown]
# Исходные данные содержат 2 типа данных: количественные и категориальные. К категориальным признакам относятся столбцы 'geography' и 'gender'. Остальные количественные, с которых начнем исследование признаков.

# %%
# Функция визуализации данных для исследования признаков
def grafik(col):
    f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
    title_col_box = 'Диаграмма "ящик с усами" ' + col
    title_col_gist = 'Гистограмма данных ' + col
    title_col_kde = 'Распределение данных ' + col    
    sns.boxplot(x=col, data=df, color='red', ax=ax1).set(title=title_col_box)
    histos = df[col].hist(bins=20, ax=ax2).set(title=title_col_gist, 
                            xlabel="Объем", ylabel=col)
    # Построим распределение значений на графике
    sns.kdeplot(data=df[[col]], fill=True, ax=ax3)
    plt.title(title_col_kde)
    plt.xlabel(col)
    plt.ylabel('Плотность')
    print(df[col].describe())
    return

# %% [markdown]
# ### 3.1. Исследование количественного признака 'credit_score'

# %% [markdown]
# Credit_score — кредитный рейтинг.<br>

# %%
grafik('credit_score')
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: credit_score, dtype: float64

# %% [markdown]
# Стандартное отклонение (далее - std) характеризует разброс величин и показывает, насколько значения в выборке отличаются от среднего арифметического (mean). Std позволяет понять природу распределения и выяснить, насколько значения однородны. Данные в признаке Credit_score характеризуютя большим стандартным отклонением, что говорит о наличии серьёзных аномалий или выбросов. Диаграмма "Ящик с усами" это подтверждает. Явно видет значительный выброс в левом стороне межквартильного интервала. А гистограмма и распределение данных Credit_score иллюстрируют скошенность данных в левую сторону - набор данных с отрицательной скошенностью.

# %%
# Посмотрим на выбросы
print('Количество строк с выбросами по кредитному рейтингу < 400: ', df.query('credit_score < 400').shape[0], 'из ', df.shape[0], ' строк.')
vol = df.query('credit_score < 400').shape[0]/df.shape[0]
print('Доля аномалий в общем объеме данных составляет:', f'{vol:.2%}.')
# Out:
# Количество строк с выбросами по кредитному рейтингу < 400:  19 из  10000  строк.
# Доля аномалий в общем объеме данных составляет: 0.19%.

# %%
df.query('credit_score < 400').head()
# Out:
#       credit_score geography  gender  age  tenure    balance  num_of_products  \
# 7              376   Germany  Female   29       4  115046.74                4
# 942            376    France  Female   46       5       0.00                1
# 1193           363     Spain  Female   28       6  146098.43                3
# 1201           399   Germany    Male   46       2  127655.22                1
# 1405           359    France  Female   44       5  128747.69                1
#
#       has_cr_card  is_active_member  estimated_salary  exited
# 7               1                 0         119346.88       1
# 942             1                 0         157333.69       1
# 1193            1                 0         100615.14       1
# 1201            1                 0         139994.68       1
# 1405            1                 0         146955.71       1

# %% [markdown]
# Всего 19 клиентов из 10000 имеют аномальный кредитный рейтинг, менее 400. Что характерно, баланс на счёте у таких клиентов не более 200 тыс.руб. Проверим уровень кредитного рейтинга других категорий клиентов с таким же уровнем баланса.

# %%
print('Количество строк с выбросами по кредитному рейтингу < 400: ', df.query('credit_score < 400').shape[0], 'из ', df.shape[0], ' строк.')
print('Средний кредитный рейтинг аномальных клиентов: ', round(df.query('credit_score < 400')['credit_score'].mean(),))
print('Количество строк по клиентам с балансом клиентов < 150 тыс.руб.: ', df.query('balance < 150000').shape[0], 'из ', df.shape[0], ' строк.')
print('Средний кредитный рейтинг клиентов с балансом < 200 тыс.руб.: ', round(df.query('balance < 150000')['credit_score'].mean(),))
# Out:
# Количество строк с выбросами по кредитному рейтингу < 400:  19 из  10000  строк.
# Средний кредитный рейтинг аномальных клиентов:  368
# Количество строк по клиентам с балансом клиентов < 150 тыс.руб.:  9031 из  10000  строк.
# Средний кредитный рейтинг клиентов с балансом < 200 тыс.руб.:  650

# %% [markdown]
# Исследование показало, что в данном случае оператором банка (либо системой) был начислен ошибочный кредитный рейтинг по 19 клиентам. Он почти вдвое ниже аналогичных клиентов. В связи с ничтожно малой долей антомалий, целесообразно эти строки удалить из датасета.

# %%
df = df[df.credit_score > 400]

# %%
grafik('credit_score')
# Out:
# count    9981.000000
# mean      651.067528
# std        95.950021
# min       401.000000
# 25%       584.000000
# 50%       652.000000
# 75%       718.000000
# max       850.000000
# Name: credit_score, dtype: float64

# %% [markdown]
# Распределение данных стало более однородным, однако с небольшим отрицательной скошенностью.

# %% [markdown]
# ### 3.2. Исследование количественного признака 'age'

# %% [markdown]
# Исследование данных в столбце age — возраст.<br>

# %%
grafik('age')
# Out:
# count    9981.000000
# mean       38.912634
# std        10.487887
# min        18.000000
# 25%        32.000000
# 50%        37.000000
# 75%        44.000000
# max        92.000000
# Name: age, dtype: float64

# %% [markdown]
# Данные в признаке Age характеризуютя стандартным отклонением в 10 лет. Диаграмма "Ящик с усами" говорит о наличии серьёзных аномалий или выбросов в правой стороне межквартильного интервала. Гистограмма и распределение данных Age подтверждает это - набор данных с положительной скошенностью.

# %%
# Посмотрим на выбросы
print('Количество строк с выбросами по возрасту > 61 года: ', df.query('age > 60').shape[0], 'из ', df.shape[0], ' строк.')
vol = df.query('age > 60').shape[0]/df.shape[0]
print('Доля аномалий в общем объеме данных составляет:', f'{vol:.2%}.')
# Out:
# Количество строк с выбросами по возрасту > 61 года:  464 из  9981  строк.
# Доля аномалий в общем объеме данных составляет: 4.65%.

# %% [markdown]
# Проверим состав клиентов старше 60 лет, у которых по данным банка предполагаемая зарплата выше 100 тыс.руб., а на балансе 0 руб.

# %%
df.query('age > 60 and balance == 0 and estimated_salary > 100000').head()
# Out:
#      credit_score geography  gender  age  tenure  balance  num_of_products  \
# 85            652     Spain  Female   75       5      0.0                2
# 104           670     Spain  Female   65       1      0.0                1
# 230           673    France    Male   72       1      0.0                2
# 252           681    France  Female   79       0      0.0                2
# 310           652    France  Female   80       4      0.0                2
#
#      has_cr_card  is_active_member  estimated_salary  exited
# 85             1                 1         114675.75       0
# 104            1                 1         177655.68       1
# 230            0                 1         111981.19       0
# 252            0                 1         170968.99       0
# 310            1                 1         188603.07       0

# %%
print('Количество клиентов старше 60 лет с з/п выше 100 руб.руб. и нулевым остатком на балансе: ', 
      df.query('age > 60 and balance == 0 and estimated_salary > 100000').shape[0], 'чел.')
vol = df.query('age > 60 and balance == 0 and estimated_salary > 100000').shape[0]/df.shape[0]
print('Доля аномалий в общем объеме данных составляет:', f'{vol:.2%}.')
# Out:
# Количество клиентов старше 60 лет с з/п выше 100 руб.руб. и нулевым остатком на балансе:  83 чел.
# Доля аномалий в общем объеме данных составляет: 0.83%.

# %% [markdown]
# Здесь я б предложил руководству банка обратить внимание на такой контингент клиентов. Их доля составляет почти 1%, что довольно много для самостоятельного принятия решения об отнесении этой категории клиентов к аномалиям. Однако подобные аномалии могут существенно исказить качество прогнозируемой модели. Пока в данном случае оставим аномалии без изменений.

# %% [markdown]
# ### 3.3. Исследование количественного признака 'tenure'

# %% [markdown]
# Исследование данных в столбце tenure — сколько лет человек является клиентом банка.<br>

# %%
grafik('tenure')
# Out:
# count    9981.00000
# mean        4.99990
# std         2.75908
# min         0.00000
# 25%         3.00000
# 50%         5.00000
# 75%         7.00000
# max        10.00000
# Name: tenure, dtype: float64

# %% [markdown]
# Практически идеальное распределение данных, которое не требует предобработки.

# %% [markdown]
# ### 3.4. Исследование количественного признака 'balance'

# %% [markdown]
# Исследование данных в столбце balance — баланс на счёте.<br>

# %%
grafik('balance')
# Out:
# count      9981.000000
# mean      76455.866471
# std       62401.960813
# min           0.000000
# 25%           0.000000
# 50%       97133.920000
# 75%      127631.620000
# max      250898.090000
# Name: balance, dtype: float64

# %% [markdown]
# Вот кстати классический пример отрицательной скошенности данных. Причина всему - это нулевой баланс клиента. Сейчас проверим, сколько таких клиентов и что это за клиенты.

# %%
# Посмотрим на выбросы
print('Количество клиентов с нулевым балансом: ', df.query('balance == 0').shape[0], 'из ', df.shape[0], ' чел.')
vol = df.query('balance == 0').shape[0]/df.shape[0]
print('Доля аномалий в общем объеме данных составляет:', f'{vol:.2%}.')
# Out:
# Количество клиентов с нулевым балансом:  3612 из  9981  чел.
# Доля аномалий в общем объеме данных составляет: 36.19%.

# %% [markdown]
# Это довольно огромный процент предполагаемой аномалии. Характер скошенности данных резко отрицательный. Плотность клиентов с нулевым балансом пости в 1,5 раза выше нормального распределения.

# %%
# посмотрим на распределение возраста клиентов с нулевым балансом
print('*' * 20)
print('Характер распределения данных по клиентам с нулевым балансом на счету в банке')
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
title_ax1 = 'Распределение по возврасту клиента'
title_ax2 = 'Распределение по предполагаемой зарплате'
title_ax3 = 'Распределение по количеству открытых продуктов' 
df.query('balance == 0')['age'].hist(bins=70, ax=ax1).set(title=title_ax1, xlabel="Возраст, лет", ylabel="Клиентов, чел.")
df.query('balance == 0')['estimated_salary'].hist(bins=70, ax=ax2).set(title=title_ax2, xlabel="Зарплата, руб.", ylabel="Клиентов, чел.")
df.query('balance == 0')['num_of_products'].hist(bins=10, ax=ax3).set(title=title_ax3, xlabel="Количество продуктов банка, используемых клиентом", ylabel="Клиентов, чел.")

#is_active_member
#NumOfProducts
# Out:
# ********************
# Характер распределения данных по клиентам с нулевым балансом на счету в банке
# [Text(0.5, 1.0, 'Распределение по количеству открытых продуктов'),
#  Text(0.5, 0, 'Количество продуктов банка, используемых клиентом'),
#  Text(0, 0.5, 'Клиентов, чел.')]

# %% [markdown]
# Характер распределения данных по клиентам с нулевым балансом показывает положительную скошенность, без выбросов и аномалий. Гипотеза аномальности данной категории клиентов не оправдана. Потому что клиенты с нулевым балансом на счету являются не только пользователями продуктов банка, но и предполагаемая зарплата клиентов равномерно распределена в пределах от 0 до 200 тыс.руб.<br>
#
# Анализ данных свидетельствует о том, что львиная доля клиентов не держит на счетах свободные средства, хотя и является активной частью потребительского рынка. Напомним, это 36.19% клиентов от общей базы. Стоить рекомендовать руководству банк о необходимости проведения акционной работы в области перевода клиентской базы на зарплатные проекты, тогда и характер распределения данных станет более нормализованным, и доля лоляльных клиентов банка будет существенно выше. Согласитесь, если клиент будет обслуживаться на зарплатном проекте, то и доля свободных средств в банке станет существенно выше.

# %% [markdown]
# ### 3.5. Исследование количественного признака 'num_of_products'

# %% [markdown]
# Исследование данных в столбце num_of_products — количество продуктов банка, используемых клиентом.<br>

# %%
grafik('num_of_products')
# Out:
# count    9981.000000
# mean        1.530408
# std         0.580928
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: num_of_products, dtype: float64

# %% [markdown]
# Характер распределения данных по клиентам показывает отрицательную скошенность. Имебтся выбросы в районе 4-х используемых продуктов банка. Ниже исследует эту категорию выбросов отдельно.

# %%
# Посмотрим на выбросы
print('Количество клиентов с продуктам > 3: ', df.query('num_of_products > 3').shape[0], 'из ', df.shape[0], ' чел.')
vol = df.query('num_of_products > 3').shape[0]/df.shape[0]
print('Доля аномалий в общем объеме данных составляет:', f'{vol:.2%}.')
# Out:
# Количество клиентов с продуктам > 3:  59 из  9981  чел.
# Доля аномалий в общем объеме данных составляет: 0.59%.

# %%
# посмотрим на распределение возраста клиентов с нулевым балансом
print('*' * 20)
print('Характер распределения данных по клиентам с большим объемом открытых продуктов в банке')
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
title_ax1 = 'Распределение по возврасту клиента'
title_ax2 = 'Распределение по предполагаемой зарплате'
title_ax3 = 'Распределение по балансу на счету' 
df.query('num_of_products > 3')['age'].hist(bins=20, ax=ax1).set(title=title_ax1, xlabel="Возраст, лет", ylabel="Клиентов, чел.")
df.query('num_of_products > 3')['estimated_salary'].hist(bins=20, ax=ax2).set(title=title_ax2, xlabel="Зарплата, руб.", ylabel="Клиентов, чел.")
df.query('num_of_products > 3')['balance'].hist(bins=10, ax=ax3).set(title=title_ax3, xlabel="Баланс на счету клиента, руб.", ylabel="Клиентов, чел.")

#is_active_member
#NumOfProducts
# Out:
# ********************
# Характер распределения данных по клиентам с большим объемом открытых продуктов в банке
# [Text(0.5, 1.0, 'Распределение по балансу на счету'),
#  Text(0.5, 0, 'Баланс на счету клиента, руб.'),
#  Text(0, 0.5, 'Клиентов, чел.')]

# %% [markdown]
# Объем клиентов с количеством продуктов банка, используемых клиентом, более 3-х составляет 0.59%. Характер данной категории клиентов говорит о достаточно достоверных данных в БД банка по ним. Из них почти 80% держат средства на счету банка.

# %% [markdown]
# ### 3.6. Исследование количественного признака 'has_cr_card'

# %% [markdown]
# Исследование данных в столбце num_of_products — наличие кредитной карты.<br>

# %%
grafik('has_cr_card')
# Out:
# count    9981.000000
# mean        0.705240
# std         0.455958
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: has_cr_card, dtype: float64

# %%
# Посмотрим на выбросы
print('Количество клиентов с картами банка: ', df.query('has_cr_card == 1').shape[0], 'из ', df.shape[0], ' чел.')
vol = df.query('has_cr_card == 1').shape[0]/df.shape[0]
print('Доля аномалий в общем объеме данных составляет:', f'{vol:.2%}.')
# Out:
# Количество клиентов с картами банка:  7039 из  9981  чел.
# Доля аномалий в общем объеме данных составляет: 70.52%.

# %% [markdown]
# Бинарный характер распределения данных. Можно сказать, что основная доля клиентов имеют кредитные карты банка.

# %% [markdown]
# ### 3.7. Исследование количественного признака 'is_active_member'

# %% [markdown]
# Исследование данных в столбце is_active_member — активность клиента.<br>

# %%
grafik('is_active_member')
# Out:
# count    9981.000000
# mean        0.515479
# std         0.499785
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: is_active_member, dtype: float64

# %%
# Посмотрим на выбросы
print('Количество активных клиентов банка: ', df.query('is_active_member == 1').shape[0], 'из ', df.shape[0], ' чел.')
vol = df.query('is_active_member == 1').shape[0]/df.shape[0]
print('Доля аномалий в общем объеме данных составляет:', f'{vol:.2%}.')
# Out:
# Количество активных клиентов банка:  5145 из  9981  чел.
# Доля аномалий в общем объеме данных составляет: 51.55%.

# %% [markdown]
# Бинарный характер распределения данных. Половина клиентов активна, половина нет. Менеджменту банка стоит обратить на этот факт более пристальное внимание.

# %% [markdown]
# ### 3.8. Исследование количественного признака 'estimated_salary'

# %% [markdown]
# Исследование данных в столбце estimated_salary — предполагаемая зарплата клиента.<br>

# %%
grafik('estimated_salary')
# Out:
# count      9981.000000
# mean     100037.449178
# std       57521.103642
# min          11.580000
# 25%       50908.480000
# 50%      100127.710000
# 75%      149381.320000
# max      199992.480000
# Name: estimated_salary, dtype: float64

# %% [markdown]
# Практически идеальное распределение данных, которое не требует предобработки.

# %% [markdown]
# ### 3.9. Исследование целевого признака 'exited'.

# %% [markdown]
# В датасете имеются столбцы 'Geography' и 'Gender' с категориальными признаками. Чтобы наше исследование прошло удачно, нужно будет преобразовать текстовые признаки столбцов в числовые. Новые числовые признаки по столбцам 'Geography' и 'Gender' называются дамми-переменными, или дамми-признаками. Применим несколько техник кодирования категриальных признаков в разделе обучения модели.

# %% [markdown]
# Целевой признак Exited — факт ухода клиента, содержит бинарную информацию (0 - Нет, 1 - Да).

# %%
df["exited"].value_counts()
# Out:
# 0    7963
# 1    2018
# Name: exited, dtype: int64

# %%
df["exited"].value_counts().plot(
    title='Соотношение значений по Exited',
    xlabel='Значения по целевому признаку Exited',
    ylabel='Количество, шт.',    
    kind='bar',
    stacked=True,
    grid=True,
    color='green',
    width=0.9,
    figsize=(8,3)
    )
# Out:
# <Axes: title={'center': 'Соотношение значений по Exited'}, xlabel='Значения по целевому признаку Exited', ylabel='Количество, шт.'>

# %%
print("Соотношение значений составляет: 1 /",round(len(df[df["exited"] == 0])/len(df[df["exited"] == 1])),)
# Out:
# Соотношение значений составляет: 1 / 4

# %% [markdown]
# Дисбаланс целевого признака очень сильно модет снизить качество модели прогнозирования, в связи чем в разделе обучения модели мы прибегнем к методам апсемплинга данных с целью уравновешивания бинарных классов.

# %% [markdown]
# ### 3.10. Коррелляция количественных признаков

# %% [markdown]
# *Посмотрим ещё на корреляцию данных и на диаграмме рассеяния.*

# %%
# Проверка коррелляции данных в таблице
def plot_corr_heatmap(coeff, title):
    """
    Функция для отрисовки матрицы корелляции с использованием тепловой карты.
    
    coeff: pd.DataFrame, корелляционная матрица
    title: str, название графика
    """
    
    ax = sns.heatmap(
        coeff,
        annot=True,                                             # добавляем численные значения в каждую строчку
        fmt='.2f',
        mask=np.triu(np.ones_like(coeff)),                      # отображаем только нижний треугольник матрицы
        cmap='coolwarm',                                        # выбираем цветовую палитру
        cbar=False,                                             # отключаем полосу цвета
        xticklabels=coeff.columns[:-1],                         # устанавливаем подписи, убираем последнюю
        yticklabels=coeff.columns[1:].insert(0, ''),            # устанавливаем подписи, скрываем первую
        #linewights=1,
    )
    ax.set_facecolor('white')                                   # устанавливаем цвет фона
    
    plt.tick_params(bottom=False, left=False)                   # отключаем отображение засечек
    plt.title(title, y=0.9, font=dict(size=15, family='sans-serif'))

# %%
plot_corr_heatmap(df.corr(), 'Корелляционная матрица')

# %% [markdown]
# Коррелляция количественных признаков крайне мала, чтобы выявить хоть малейшую взаимосвязь параметров.

# %% [markdown]
# <div style="border:solid gray 3px; padding: 20px">
# <b> </b>
#
# **Вывод по разделу 3. Исследовательский анализ.**
#
# Исходный датасет Churn.csv содержит как количественные, так и категориальные признаки. Не считая явные аномальные выбросы в признаке Credit_score — кредитный рейтинг, все остальные признаки имеют характер распределения данных достаточно достоверный. Часть признаков имеет выбросы, но подобные аномалии требуют отдельного изучения вместе с менеджментом банка.
#
# К примеру, доля клиентов старше 60 лет с з/п выше 100 руб.руб. и нулевым балансом на счете составляет почти 1% объема всей клиентской базы. При этом доля клиентов с нулевым балансом довольно высока: 36.19%. Плотность этих клиентов почти в 1,5 раза выше нормального распределения. Гипотеза аномальности данной категории клиентов не оправдана, так как выявленные клиенты являются не только активными пользователями продуктов банка, но их предполагаемая зарплата равномерно распределена в пределах от 0 до 200 тыс.руб. без явных диспропорций.
#
# Необходимо понять природу данного характера диспропорций. Возможно требуется проведение акционной работы в области перевода клиентской базы на зарплатные проекты, тогда и характер распределения данных станет более нормализованным, а доля лояльных клиентов банка станет существенно выше.
#
# Проверка на корреляцию данных показала существенного коллинеарного влияния признаков друг на друга. Это положительно скажется на модели машинного обучения.

# %% [markdown]
# ## 4. Обучение моделей

# %% [markdown]
# Целевой признак - категориальный, то есть надо решить задачу бинарной (двоичной) классификации фактов ухода клиента из банка (остался - 0, ушёл - 1). Так как стоит задача на классификацию по типу категориальных переменных, то выбор ограничим следующими моделями:
#
# - Логическая регрессия
# - Случайный лес
# - CatBoostRegressor
# - LGBMRegressor

# %% [markdown]
# Кодирование категориальных признаков можно произвести несколькими способами. Воспользуемся тремя способами One Hot Encoding, Ordinal Encoder и Ручным апсемплингом в фолдах.
#
# **One Hot Encoding:** Общий альтернативный подход кодирования называется унитарным кодированием (One Hot Encoding). Основная ее стратегия состоит в том, чтобы преобразовать значение каждой категории в новый столбец и присвоить столбцу значение 1 или 0 (Истина / Ложь). Это дает преимущество в том, что значение не взвешивается неправильно, но имеет обратную сторону добавления дополнительных столбцов в набор данных. Pandas поддерживает эту возможность с помощью get_dummies.
#
# **Ordinal Encoder:** Использование в pandas OHE проще для понимания, но подход scikit является оптимальным, потому что перед нами стоит задача простроения прогнозной модели. Чтобы выполнить кодирование меток в признаках 'geography' и 'gender' необходимо создать экземпляр объекта OrdinalEncoder и произвести fit_transform данных.
#
# **Ручной апсемплинг в фолдах:** Мы должны разбить данные на тренировочный и валидационный фолды. Затем, на каждом фолде, нам нужно апсемплить меньший класс, обучить классификатор на тренировочных данных, валидировать классификатор на оставшемся фолде.

# %%
# Разбиение на подвыборки для кросс-валидации
CV = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# %%
# Целевой признак 'exited' — факт ухода клиента
X = df.drop('exited', axis=1)
y = df['exited']

# %% [markdown]
# *Для проверки модели на правильность предсказаний исходные выборки должны быть поделены на 3 части: исходную, обучающую и тестовую.<br>
# Исходные данные разобъём в соотношении 3:1:1.*
#
# *► Обучающая выборка: 60%*<br>
# *► Валидационная выборка: 20%*<br>
# *► Тестовая выборка: 20%*

# %% [markdown]
# **One Hot Encoding**

# %%
X_ohe = pd.get_dummies(X, columns=["gender", "geography"], prefix=["gender", "geography"])
X_ohe.head(5)
# Out:
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42       2       0.00                1            1
# 1           608   41       1   83807.86                1            0
# 2           502   42       8  159660.80                3            1
# 3           699   39       1       0.00                2            0
# 4           850   43       2  125510.82                1            1
#
#    is_active_member  estimated_salary  gender_Female  gender_Male  \
# 0                 1         101348.88              1            0
# 1                 1         112542.58              1            0
# 2                 0         113931.57              1            0
# 3                 0          93826.63              1            0
# 4                 1          79084.10              1            0
#
#    geography_France  geography_Germany  geography_Spain
# 0                 1                  0                0
# ...

# %% [markdown]
# **Ordinal Encoder**

# %%
ord_enc = OrdinalEncoder()
X_ord = X.copy()
X_ord["gender_code"] = ord_enc.fit_transform(X_ord[["gender"]])
X_ord["geography_code"] = ord_enc.fit_transform(X_ord[["geography"]])
X_ord.drop(['gender', 'geography'], axis= 1 , inplace= True )
X_ord.head(5)
# Out:
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42       2       0.00                1            1
# 1           608   41       1   83807.86                1            0
# 2           502   42       8  159660.80                3            1
# 3           699   39       1       0.00                2            0
# 4           850   43       2  125510.82                1            1
#
#    is_active_member  estimated_salary  gender_code  geography_code
# 0                 1         101348.88          0.0             0.0
# 1                 1         112542.58          0.0             2.0
# 2                 0         113931.57          0.0             0.0
# 3                 0          93826.63          0.0             0.0
# 4                 1          79084.10          0.0             2.0

# %% [markdown]
# ### 4.1. Разбиение датасета на 3 набора: Train, Valid, Test (OHE, OE, Manual)

# %% [markdown]
# Данная процедура необходима для сравнения качества моделей на разных способах категоризации данных

# %% [markdown]
# **Разбиение One Hot Encoding датасета**

# %%
X_train_ohe, X_intermed_ohe, y_train_ohe, y_intermed_ohe = \
    train_test_split(
    X_ohe, y, 
    test_size=0.4, \
    random_state=RANDOM_STATE)
X_valid_ohe, X_test_ohe, y_valid_ohe, y_test_ohe = \
    train_test_split(
    X_intermed_ohe, 
    y_intermed_ohe, 
    test_size=0.5, \
    random_state=RANDOM_STATE)

# %%
print(
    f'Получились One Hot Encoding выборки в следующих пропорциях:\n'
    f'{(len(X_train_ohe)/len(X)):.0%} — тренировочная, размер: {X_train_ohe.shape};\n'
    f'{(len(X_valid_ohe)/len(X)):.0%} — валидационная, размер: {X_valid_ohe.shape};\n'
    f'{(len(X_test_ohe)/len(X)):.0%} — тестовая, размер: {X_test_ohe.shape}.'
)
# Out:
# Получились One Hot Encoding выборки в следующих пропорциях:
# 60% — тренировочная, размер: (5988, 13);
# 20% — валидационная, размер: (1996, 13);
# 20% — тестовая, размер: (1997, 13).

# %% [markdown]
# **Разбиение Ordinal Encoder датасета**

# %%
X_train_ord, X_intermed_ord, y_train_ord, y_intermed_ord = \
    train_test_split(
    X_ord, y, 
    test_size=0.4, \
    random_state=RANDOM_STATE)
X_valid_ord, X_test_ord, y_valid_ord, y_test_ord = \
    train_test_split(
    X_intermed_ord, 
    y_intermed_ord, 
    test_size=0.5, \
    random_state=RANDOM_STATE)

# %%
print(
    f'Получились Ordinal Encoder выборки в следующих пропорциях:\n'
    f'{(len(X_train_ord)/len(X)):.0%} — тренировочная, размер: {X_train_ord.shape};\n'
    f'{(len(X_valid_ord)/len(X)):.0%} — валидационная, размер: {X_valid_ord.shape};\n'
    f'{(len(X_test_ord)/len(X)):.0%} — тестовая, размер: {X_test_ord.shape}.'
)
# Out:
# Получились Ordinal Encoder выборки в следующих пропорциях:
# 60% — тренировочная, размер: (5988, 10);
# 20% — валидационная, размер: (1996, 10);
# 20% — тестовая, размер: (1997, 10).

# %% [markdown]
# **Ручной апсемплинг в фолдах**

# %%
X_train, X_intermed, y_train, y_intermed = \
    train_test_split(
    X_ord, y, 
    test_size=0.4, \
    random_state=RANDOM_STATE)
X_valid, X_test, y_valid, y_test = \
    train_test_split(
    X_intermed, 
    y_intermed, 
    test_size=0.5, \
    random_state=RANDOM_STATE)

# %%
print(
    f'Получились Ordinal Encoder выборки в следующих пропорциях:\n'
    f'{(len(X_train)/len(X)):.0%} — тренировочная, размер: {X_train.shape};\n'
    f'{(len(X_valid)/len(X)):.0%} — валидационная, размер: {X_valid.shape};\n'
    f'{(len(X_test)/len(X)):.0%} — тестовая, размер: {X_test.shape}.'
)
# Out:
# Получились Ordinal Encoder выборки в следующих пропорциях:
# 60% — тренировочная, размер: (5988, 10);
# 20% — валидационная, размер: (1996, 10);
# 20% — тестовая, размер: (1997, 10).

# %%
# Сюда будем сохранять лучшие значения для разных моделей
# F1-мера train
scores = []
scores = pd.DataFrame(columns=['train_F1'])
# F1-мера valid
scores_valid = []
scores_valid = pd.DataFrame(columns=['valid_F1'])
# recall valid
scores_recall = []
scores_recall = pd.DataFrame(columns=['valid_recall'])
# precision valid
scores_precision = []
scores_precision = pd.DataFrame(columns=['valid_precision'])
# auc_roc valid
scores_auc_roc = []
scores_auc_roc = pd.DataFrame(columns=['valid_auc_roc'])

# %%
# Функция для обучения модели с подборкой гиперпараметров и кросс-валидацией

def train_model(model, parameters, X, y, X_valid, y_valid, data_type=''):
    gscv = RandomizedSearchCV(model, parameters, n_jobs=-1, cv=CV, scoring='f1', refit=True, verbose=3)
    gscv.fit(X, y)
    
    if gscv.best_params_:
        print('\nBest parameters:')
        for param_name, val in gscv.best_params_.items():
            print(f'{param_name}: {val}')
            
    estimator_name = gscv.best_estimator_.__class__.__name__
    
    if estimator_name == 'Pipeline':
        estimator_name = gscv.best_estimator_[-1].__class__.__name__
        
    data_type = ' + ' + data_type if data_type else ''
    
    # Строим результаты сравнения истинных значений с предсказанными
    fig, ax = plt.subplots(1, 1, figsize=(5.5, 4.5))
    ax.set_title(estimator_name + data_type)
    RocCurveDisplay.from_estimator(gscv.best_estimator_, X, y, ax=ax)
    plt.text(0.2, 0.95, f'Train F1: {gscv.best_score_:.2f}', horizontalalignment='center', verticalalignment='center',
             transform=ax.transAxes, bbox=dict(facecolor='white', alpha=0.7))
    plt.show
    
    scores.loc[estimator_name + data_type] = [gscv.best_score_]
    predictions_valid = gscv.predict(X_valid)
    # посчёт полноты модели recall по вадидацинной выборке                    
    recall = recall_score(y_valid, predictions_valid)
    # посчёт точности модели precision по вадидацинной выборке                      
    precision = precision_score(y_valid, predictions_valid)    
    # посчёт средней гармонической полноты и точности модели по вадидацинной выборке                      
    f1 = f1_score(y_valid, predictions_valid) 
    # вычисление вероятности классов вычисляет функция
    probabilities_valid = gscv.predict_proba(X_valid)
    probabilities_one_valid = probabilities_valid[:, 1]
    auc_roc = roc_auc_score(y_valid, probabilities_one_valid)    
      
    scores_valid.loc[estimator_name + data_type] = f1
    scores_recall.loc[estimator_name + data_type] = recall    
    scores_precision.loc[estimator_name + data_type] = precision    
    scores_auc_roc.loc[estimator_name + data_type] = auc_roc
   
    return gscv.best_estimator_

# %% [markdown]
# ### 4.2. Выбор модели обучения

# %% [markdown]
# #### 4.2.1. Стандартный подход, без upsempling 'Exited'

# %%
print("Соотношение значений в целевом признаке составляет: 1 /", round((y == 0).sum()/(y == 1).sum(),))
# Out:
# Соотношение значений в целевом признаке составляет: 1 / 4

# %% [markdown]
# Значения в целевом признаке Exited (факт ухода клиента) сильно разбалансированы.

# %%
#print("Соотношение значений составляет: 1 /",round(len(df[df["exited"] == 0])/len(df[df["exited"] == 1])),)

# %% [markdown]
# Давайте получим базовый результат без upsempling по метрике F1, выбрав Случайный Лес.

# %%
model_rfc = RandomForestClassifier()

params_rfc = {
    'n_estimators': [50, 100, 200],
    'max_depth': [4, 6, 10, 12],
    'random_state': [RANDOM_STATE]
}

model_rfc = train_model(model_rfc, params_rfc, X_train_ohe, y_train_ohe, X_valid_ohe, y_valid_ohe, 'not upsampling OHE')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Best parameters:
# random_state: 12345
# n_estimators: 50
# max_depth: 12

# %%
y_test_predict = model_rfc.predict(X_valid_ohe)
f1_score(y_valid_ohe, y_test_predict)
# Out:
# 0.5747460087082729

# %% [markdown]
# #### 4.2.2. Использование конвейера imblearn на OHE выборке

# %% [markdown]
# Делая апсемплинг, нам нужно увеличить число строк. Imbalanced-learn обобщает конвейер, оставляя при это синтаксис и названия функций неизменными:

# %% [markdown]
# **OHE. Подбор гиперпараметров. Модель - Логистическая регрессия с апсемлингом**

# %%
params_lr = {
    'max_iter': [50, 100, 200, 1000],
    'solver': ['lbfgs', 'liblinear', 'sag', 'saga'],
    'penalty': ['l2', 'elasticnet'],
    'random_state': [RANDOM_STATE]
}

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              LogisticRegression(random_state=RANDOM_STATE))

# %%
new_params = {'logisticregression__' + key: params_lr[key] for key in params_lr}
model_lr_umba = train_model(imba_pipeline, new_params, X_train_ohe, y_train_ohe, X_valid_ohe, y_valid_ohe, 'upsampling OHE')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Best parameters:
# logisticregression__solver: liblinear
# logisticregression__random_state: 12345
# logisticregression__penalty: l2
# logisticregression__max_iter: 200

# %%
y_test_predict = model_lr_umba.predict(X_valid_ohe)
f1_score(y_valid_ohe, y_test_predict)
# Out:
# 0.44847485572959606

# %% [markdown]
# **OHE. Подбор гиперпараметров. Модель - Случайный лес с апсемлингом.**

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              RandomForestClassifier(n_estimators=50, random_state=RANDOM_STATE))

# %%
new_params = {'randomforestclassifier__' + key: params_rfc[key] for key in params_rfc}
model_rfc_umba = train_model(imba_pipeline, new_params, X_train_ohe, y_train_ohe, X_valid_ohe, y_valid_ohe, 'upsampling OHE')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Best parameters:
# randomforestclassifier__random_state: 12345
# randomforestclassifier__n_estimators: 100
# randomforestclassifier__max_depth: 10

# %%
y_test_predict = model_rfc_umba.predict(X_valid_ohe)
f1_score(y_valid_ohe, y_test_predict)
# Out:
# 0.5876662636033858

# %% [markdown]
# **OHE. Подбор гиперпараметров. Модель CatBoostClassifier с апсемлингом.**

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              CatBoostClassifier(random_state=RANDOM_STATE))

# %%
params_cbc = {
    'learning_rate': [0.01, 0.05, 0.1, 0.3],
    'depth': [5, 8, 10],
    'n_estimators': [100, 300, 500],
    'verbose': [False],
    'random_state': [RANDOM_STATE]
}

# %%
new_params = {'catboostclassifier__' + key: params_cbc[key] for key in params_cbc}
model_cbc_umba_ohe = train_model(imba_pipeline, new_params, X_train_ohe, y_train_ohe, X_valid_ohe, y_valid_ohe, 'upsampling OHE')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Best parameters:
# catboostclassifier__verbose: False
# catboostclassifier__random_state: 12345
# catboostclassifier__n_estimators: 100
# catboostclassifier__learning_rate: 0.1
# catboostclassifier__depth: 5

# %%
y_test_predict = model_cbc_umba_ohe.predict(X_valid_ohe)
f1_score(y_valid_ohe, y_test_predict)
# Out:
# 0.6115702479338843

# %% [markdown]
# **OHE. Подбор гиперпараметров. Модель LGBMClassifier с апсемлингом.**

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              LGBMClassifier(random_state=RANDOM_STATE))

# %%
params_LGBM = {
    'learning_rate': [0.01, 0.1, 0.3],
    'max_depth': [3, 6, 10],
    'random_state': [RANDOM_STATE]
}

# %%
new_params = {'lgbmclassifier__' + key: params_LGBM[key] for key in params_LGBM}
model_lgbm_umba_ohe = train_model(imba_pipeline, new_params, X_train_ohe, y_train_ohe, X_valid_ohe, y_valid_ohe, 'upsampling OHE')
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
#
# Best parameters:
# lgbmclassifier__random_state: 12345
# lgbmclassifier__max_depth: 3
# lgbmclassifier__learning_rate: 0.1

# %%
y_test_predict = model_lgbm_umba_ohe.predict(X_valid_ohe)
f1_score(y_valid_ohe, y_test_predict)
# Out:
# 0.6133651551312649

# %% [markdown]
# #### 4.2.3. Использование конвейера imblearn на Ordinal Encoder выборке

# %% [markdown]
# **Ordinal Encoder. Подбор гиперпараметров. Модель - Логистическая регрессия с апсемлингом.**

# %%
params_lr = {
    'max_iter': [50, 100, 200, 1000],
    'solver': ['lbfgs', 'liblinear', 'sag', 'saga'],
    'penalty': ['l1', 'l2', 'elasticnet'],
    'class_weight': ['balanced', 'dict'],
    'random_state': [RANDOM_STATE]
}

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              LogisticRegression(random_state=RANDOM_STATE))

# %%
new_params = {'logisticregression__' + key: params_lr[key] for key in params_lr}
model_lr_umba = train_model(imba_pipeline, new_params, X_train_ord, y_train_ord, X_valid_ord, y_valid_ord, 'upsampling ORD')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Best parameters:
# logisticregression__solver: saga
# logisticregression__random_state: 12345
# logisticregression__penalty: l2
# logisticregression__max_iter: 200
# logisticregression__class_weight: balanced

# %%
y_test_predict = model_lr_umba.predict(X_valid_ord)
f1_score(y_valid_ord, y_test_predict)
# Out:
# 0.37273295809881174

# %% [markdown]
# **Ordinal Encoder. Подбор гиперпараметров. Модель - Случайный лес с апсемлингом.**

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              RandomForestClassifier(n_estimators=50, random_state=RANDOM_STATE))

# %%
new_params = {'randomforestclassifier__' + key: params_rfc[key] for key in params_rfc}
model_rfc_umba_ord = train_model(imba_pipeline, new_params, X_train_ord, y_train_ord, X_valid_ord, y_valid_ord, 'upsampling ORD')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Best parameters:
# randomforestclassifier__random_state: 12345
# randomforestclassifier__n_estimators: 100
# randomforestclassifier__max_depth: 10

# %%
y_test_predict = model_rfc_umba_ord.predict(X_valid_ord)
f1_score(y_valid_ord, y_test_predict)
# Out:
# 0.5850178359096313

# %% [markdown]
# **Ordinal Encoder. Подбор гиперпараметров. Модель CatBoostClassifier с апсемлингом.**

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              CatBoostClassifier(random_state=RANDOM_STATE))

# %%
new_params = {'catboostclassifier__' + key: params_cbc[key] for key in params_cbc}
model_cbc_umba_oe = train_model(imba_pipeline, new_params, X_train_ord, y_train_ord, X_valid_ord, y_valid_ord, 'upsampling ORD')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Best parameters:
# catboostclassifier__verbose: False
# catboostclassifier__random_state: 12345
# catboostclassifier__n_estimators: 100
# catboostclassifier__learning_rate: 0.1
# catboostclassifier__depth: 8

# %%
y_test_predict = model_cbc_umba_oe.predict(X_valid_ord)
f1_score(y_valid_ord, y_test_predict)
# Out:
# 0.6090047393364929

# %% [markdown]
# **Ordinal Encoder. Подбор гиперпараметров. Модель LGBMClassifier с апсемлингом.**

# %%
imba_pipeline = make_pipeline(SMOTE(random_state=RANDOM_STATE), 
                              LGBMClassifier(random_state=RANDOM_STATE))

# %%
new_params = {'lgbmclassifier__' + key: params_LGBM[key] for key in params_LGBM}
model_lgbm_umba_oe = train_model(imba_pipeline, new_params, X_train_ord, y_train_ord, X_valid_ord, y_valid_ord, 'upsampling ORD')
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
#
# Best parameters:
# lgbmclassifier__random_state: 12345
# lgbmclassifier__max_depth: 3
# lgbmclassifier__learning_rate: 0.1

# %%
y_test_predict = model_lgbm_umba_oe.predict(X_valid_ord)
f1_score(y_valid_ord, y_test_predict)
# Out:
# 0.5995260663507109

# %% [markdown]
# #### 4.2.4. Ручной апсемплинг в фолдах

# %% [markdown]
# Давайте просто апсемплим тренировочные данные (мы достаточно умны, чтобы не апсемплить тестовые данные) и проверим, что мы получили равное разделение на два класса:

# %%
# Увеличение выборки - upsampling
oversample = SMOTE(random_state=RANDOM_STATE)
X_train_upsample, y_train_upsample = oversample.fit_resample(X_train, y_train)
y_train_upsample.mean()
# Out:
# 0.5

# %%
y_train_upsample.value_counts().plot(
    title='Соотношение значений по Exited',
    xlabel='Значения по целевому признаку Exited',
    ylabel='Количество, шт.',    
    kind='bar',
    stacked=True,
    grid=True,
    color='green',
    width=0.9,
    figsize=(8,3)
    )
# Out:
# <Axes: title={'center': 'Соотношение значений по Exited'}, xlabel='Значения по целевому признаку Exited', ylabel='Количество, шт.'>

# %% [markdown]
# **Ручной апсемплинг. Подбор гиперпараметров. Модель - Случайный лес.**

# %%
# Функция ручного апсемплинга в фолдах с вычислением лучшей F1
def score_model(model, params, cv=None):
    """
    Creates folds manually, and upsamples within each fold.
    Returns an array of validation (recall) scores
    """
    if cv is None:
        cv = KFold(n_splits=5, shuffle=False)

    smoter = SMOTE(random_state=RANDOM_STATE)
    
    scores_manual = []

    for train_fold_index, val_fold_index in cv.split(X_train, y_train):
        # Get the training data
        X_train_fold, y_train_fold = X_train.iloc[train_fold_index], y_train.iloc[train_fold_index]
        # Get the validation data
        X_val_fold, y_val_fold = X_train.iloc[val_fold_index], y_train.iloc[val_fold_index]

        # Upsample only the data in the training section
        X_train_fold_upsample, y_train_fold_upsample = smoter.fit_resample(X_train_fold,
                                                                           y_train_fold)
        # Fit the model on the upsampled training data
        model_obj = model(**params).fit(X_train_fold_upsample, y_train_fold_upsample)
        # Score the model on the (non-upsampled) validation data
        score_m = f1_score(y_val_fold, model_obj.predict(X_val_fold))
        scores_manual.append(score_m)
        global best_score_f1
        best_score_f1 = np.array(scores_manual).max()
    return best_score_f1

# %% [markdown]
# Сейчас мы сделаем поиск по сетке перебрав параметры. Вспомним, что комбинации параметров, которые мы ранее пробовали были:

# %%
params_rfc
# Out:
# {'n_estimators': [50, 100, 200],
#  'max_depth': [4, 6, 10, 12],
#  'random_state': [12345]}

# %%
# Перебор гиперпараметров с поиском лучшей конфигурации
score_tracker = []
for n_estimators in params_rfc['n_estimators']:
    for max_depth in params_rfc['max_depth']:
        example_params = {
            'n_estimators': n_estimators,
            'max_depth': max_depth,
            'random_state': RANDOM_STATE
        }
        example_params['recall'] = score_model(RandomForestClassifier, 
                                               example_params, cv=CV).mean()
        score_tracker.append(example_params)
        
# Какие лучшие гиперпараметры?
best_param = sorted(score_tracker, key=lambda x: x['recall'], reverse=True)[0]

# %%
# Example of the model in action
best_param.pop('recall', 0)
score_model(RandomForestClassifier, best_param, cv=CV)
# Out:
# 0.6469344608879494

# %%
# Функция для обучения модели с подборкой гиперпараметров и кросс-валидацией

def train_model_manual(model, parameters, X, y, X_valid, y_valid, data_type=''):
    #gscv = RandomizedSearchCV(model, parameters, n_jobs=-1, cv=CV, scoring='f1', refit=True, verbose=3)
    model.fit(X, y)
    estimator_name = model.__class__.__name__
    # Строим результаты сравнения истинных значений с предсказанными
        
    #scores.loc[estimator_name + data_type] = [gscv.best_score_]
    scores.loc[estimator_name + data_type] = best_score_f1
    predictions_valid = model.predict(X_valid)
    # посчёт полноты модели recall по вадидацинной выборке                    
    recall = recall_score(y_valid, predictions_valid)
    # посчёт точности модели precision по вадидацинной выборке                      
    precision = precision_score(y_valid, predictions_valid)    
    # посчёт средней гармонической полноты и точности модели по вадидацинной выборке                      
    f1 = f1_score(y_valid, predictions_valid) 
    # вычисление вероятности классов вычисляет функция
    probabilities_valid = model.predict_proba(X_valid)
    probabilities_one_valid = probabilities_valid[:, 1]
    auc_roc = roc_auc_score(y_valid, probabilities_one_valid)    
      
    scores_valid.loc[estimator_name + data_type] = f1
    scores_recall.loc[estimator_name + data_type] = recall    
    scores_precision.loc[estimator_name + data_type] = precision    
    scores_auc_roc.loc[estimator_name + data_type] = auc_roc
    
    return model

# %%
model_manual = RandomForestClassifier()
model_manual = train_model_manual(model_manual, best_param, X_train_upsample, y_train_upsample, X_valid, y_valid, ' Manual')

# %% [markdown]
# ### 4.3. Сравнение моделей обучения и проверка на адекватность

# %%
# Выведем полученные метрики для всех обученных моделей
table = scores.merge(scores_valid, left_index = True, right_index = True). \
       merge(scores_recall, left_index = True, right_index = True). \
       merge(scores_precision, left_index = True, right_index = True). \
       merge(scores_auc_roc, left_index = True, right_index = True).sort_values(by='valid_F1', ascending = False)
table
# Out:
#                                              train_F1  valid_F1  valid_recall  \
# LGBMClassifier + upsampling OHE              0.623361  0.613365      0.609005
# CatBoostClassifier + upsampling OHE          0.631418  0.611570      0.613744
# CatBoostClassifier + upsampling ORD          0.620277  0.609005      0.609005
# LGBMClassifier + upsampling ORD              0.615078  0.599526      0.599526
# RandomForestClassifier + upsampling OHE      0.607116  0.587666      0.575829
# RandomForestClassifier + upsampling ORD      0.607614  0.585018      0.582938
# RandomForestClassifier + not upsampling OHE  0.579919  0.574746      0.469194
# RandomForestClassifier Manual                0.646934  0.567568      0.547393
# LogisticRegression + upsampling OHE          0.449928  0.448475      0.644550
# LogisticRegression + upsampling ORD          0.355786  0.372733      0.706161
#
#                                              valid_precision  valid_auc_roc
# ...

# %%
table_sort = table.drop(index=['LogisticRegression + upsampling OHE'])

# %% [markdown]
# Построение сравнительного графика метрик моделей обучения и сравнение с простым классификатором DummyClassifier c целью проверки моделей на адекватность.

# %%
table_sort.plot(
    use_index=True,
    y=["train_F1", "valid_F1", "valid_recall", "valid_precision", "valid_auc_roc"],
    xlabel='Модель машинного обучения',
    ylabel='Показатель качества метрики',
    figsize=(12,5),
    title='Метрики моделей обучений'
    )
plt.rc('xtick', labelsize=7) 
plt.xticks(rotation = 90)
# Add gridlines to the plot
plt.grid(linestyle='--')
# Проверим прогресс наших моделей относительно качества константной в f1
dummy_model = DummyClassifier(strategy='constant', constant=1, random_state=RANDOM_STATE)
dummy_model.fit(X_train, y_train)
f1_dummy = f1_score(dummy_model.predict(X_valid), y_valid)
plt.axhline (y=f1_dummy, color='red', linestyle='--', label='dummy F1')
plt.legend(loc='upper left', title='Метрики')

# %% [markdown]
# <div style="border:solid gray 3px; padding: 20px">
# <b> </b>
#
# ***Вывод по разделу 4. Обучение и выбор оптимальной модели.***
#
# Исходный датасет Churn.csv содержит как количественные, так и категориальные признаки. Целевой признак 'Exited' - категориальный, поэтому надо было решить задачу бинарной (двоичной) классификации фактов ухода клиента из банка (остался - 0, ушёл - 1). Так как стояла задача на классификацию по типу категориальных переменных, то выбор ограничился следующими моделями классификации:
#
# - Логическая регрессия (LogisticRegression);
# - Случайный лес (RandomForestClassifier);
# - CatBoostRegressor (CatBoostClassifier);
# - LGBMRegressor (LGBMClassifier).
#
# Помимо прочего задача категоризации признаков решается множеством вариантов. В данном проекте были использованы 3 метода:
#
# - Быстрое кодирование (One Hot Encoding). Метод OHE основан на создании бинарных признаков, то есть преобразовании значения каждой категории в новый столбец и присвоения столбцу значение 1 или 0 (Истина / Ложь).
# - Порядковое кодирование (Ordinal Encoding). Метод основан на кодировании признаков цифрами, с помощью номера категории.
# - Ручной апсемплинг в фолдах (Manual upsample). Данные вручную разбиваются на тренировочный, валидационный и тестовый фолды. Затем, на каждом фолде производится апсемплить меньшего класса, обучение классификатора на тренировочных данных и  валидирование классификатора на оставшемся фолде.
#
# В целом, после прогонки выбранных моделей с различными вариантами категоризации train и valid и сравнения полученных метрик, наилучшие показатели получились у модели CatBoostClassifier на апсемплинговых данных по методу Ordinal Encoder. Метрика F1 на train показала 0.618962, на valid - 0.613527. При соотношение доли истинно положительных ответов (TPR) к доли ложноположительных ответов (FPR) - метрика ROC-AUC, позволяющая оценить качество модели бинарной классификации, показала также неплохие результаты 0.846328. Следует отметить, что выбранная модель остро конкурирует с LGBMClassifier + upsampling OHE. По валидационной проверке лидирует CatBoostClassifier + upsampling ORD.
#
# Для проверки моделей на вменяемость воспользовались классификатором DummyClassifier, который делает автоматические прогнозы. Проверка на адекватность выбранной модели прошла успешно, что можно видеть на визуализации метрик на графике "Метрики моделей обучений".

# %% [markdown]
# ## 5. Тестирование модели и исследование важности признаков

# %% [markdown]
# Лучшая модель оказалась LGBMClassifier на upsampling One Hot Encoding. Наилучшие параметры модели:
#
# Best parameters:
#  - lgbmclassifier__random_state: 12345
#  - lgbmclassifier__max_depth: 3
#  - lgbmclassifier__learning_rate: 0.1

# %%
# Функция для тестирования лучшей модели
def test_best_model(model, X, y, X_t, y_t):
    # Будем проводить сравнение с константной моделью
    dummy_reg = DummyClassifier(strategy='constant', constant=1, random_state=RANDOM_STATE)
    dummy_reg.fit(X, y)
    
    #model_name = model.__class__.__name__
    model_name = model[1].__class__.__name__ + ' unbalance One Hot Encoding'
    model_test_f1 = f1_score(y_t, model.predict(X_t))
    
    print(f'F1 on test data for {model_name}: {model_test_f1:.2f}')
    print(f'F1 on test data for Dummy model: {f1_score(y_t, dummy_reg.predict(X_t)):.2f}')
    
    fig, ax = plt.subplots(1, 1, figsize=(5.5, 4.5))
    plt.title(model_name)
    RocCurveDisplay.from_estimator(model, X, y, ax=ax)
    plt.text(0.2, 0.95, f'Test F1: {model_test_f1:.2f}', horizontalalignment='center', verticalalignment='center',
             transform=ax.transAxes, bbox=dict(facecolor='white', alpha=0.7))
    plt.show()
#   print(model_cbc_umba_ohe)

# %%
test_best_model(model_lgbm_umba_ohe, X_train_ohe, y_train_ohe, X_test_ohe, y_test_ohe)
# Out:
# F1 on test data for LGBMClassifier unbalance One Hot Encoding: 0.61
# F1 on test data for Dummy model: 0.35

# %% [markdown]
# Вычислим также влияние объектов из набора данных X_train_ohe на оптимизированные значения метрики F1 для объектов из входного набора данных. Важность объекта исследуем с помощью функций потери loss_function = 'F1'. Исследование проведём на наилучшей модели CatBoostClassifier с подобранным параметрами.

# %% [markdown]
# Построим важность признаков для базовых моделей, затем построим вклад модели в итоговое предсказание.

# %%
# Строим важность признаков для базовых моделей
feature_importances = pd.concat([pd.DataFrame({
          'feature': model_rfc.feature_names_in_,
          'importance': model_rfc.feature_importances_ * 100,
          'model': 'Unbalance OHE'
   })                       
]).sort_values('importance', ascending=False)

sns.barplot(y='feature', x='importance', data=feature_importances, hue='model', orient='h')
plt.title('Важность признаков')
# Out:
# Text(0.5, 1.0, 'Важность признаков')

# %% [markdown]
# <div style="border:solid gray 3px; padding: 20px">
# <b> </b>
#
# ***Вывод по разделу 5. Тестирование модели и исследование важности признаков.***
#
#
# Модель LGBMClassifier на upsampling One Hot Encoding на тестировании показала самые лучшие результаты. Разница между тренировочной, валидационной и тестовой выборками незначительная, что говорит об успешном обучении модели. Мы уложились в условия значения метрики F1. На тестовой выборке она оказалась F1 = 0.61, при показаниях F1_train = 0.623361, F1_valid = 0.613365. Полученная метрика AUC-ROC на тестовой выборке показала отличный результат - 0.89, что выше аналогичного результата на валидационной выборке (AUC-ROC_valid = 0.852186). Неплохое достигнутое качество модели. Стоит отметить высокую конкуренцию выбранной модели с CatBoostClassifier + upsampling OHE.
#
# Наиболее важные признаки, которые значительно влияют на качество предсказания, по убыванию:
# - Age - возраст;
# - NumOfProducts — количество продуктов банка, используемых клиентом;
# - Balance — баланс на счёте;
# - CreditScore — кредитный рейтинг;
# - EstimatedSalary — предполагаемая зарплата;
# - Tenure — сколько лет человек является клиентом банка;
# - IsActiveMember — активность клиента.
#
# Исследование показывает стойкую закономерность, что чем старше клиент и чем больше у него открыто продуктов в банке, тем выше вероятность того, что клиент и дальше будет пользоваться услугами банка.

# %% [markdown]
# ## 6. Отчёт по проекту

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# ***Общий вывод***
#
# 1. Для построения качественной модели машинного обучения с предельно большим значением F1-меры и приемлемым AUC ROC, была проведена предварительная обработка данных исследуемого датасета Churn.csv «Отток клиентов». На первом этапе после знакомства с данными мы избавились от пустых значений, удалили из таблицы явно неинформативные для исследования столбцы 'rowNumber', 'Surname', 'CustomerId', и привели наименования столбцов к общепринятому стандарту написания. Дубликатов обнаружено не было. Исследуемая таблица состоит из 9 количественных столбцов и 2 категориальных столбцов (geography, gender).<br>
# <br>
# 2. Вторым этапом произвели преобразование текстовых признаков категориальных столбцов 'geography' и 'gender' в числовые. Для дальнейшего анализа были применены три техники кодирования One-Hot Encoding, Ordinal Encoder и ручной апсемплинг данных.<br>
# <br>
# 3. Для подбора наилучших моделей машинного обучения датасет поделили на обучающую _train, валидную _valid (проверочную) и тестовую _test выборки в соотношении 3:1:1, используя метод train_test_split.<br>
# <br>
# 4. Проведено исследование задачи с проверкой алгоритмов машинного обучения и выбора наилучшей модели. В ходе подбора гиперпараметров наилучший результат по метрикам F1-мера и AUC ROC показала модель "LGBMClassifier" на апсемплинговой выборке с техникой кодирования  One Hot Encoding. Качество модели F1-мера на train составило 0.623361, на valid - 0.613365. Метрика качества AUC-ROC модели составила: 0.852186.<br>
# <br>
# 5. С помощью классификатора DummyClassifier проверены прогнозы как на тренировочной, так и на тестовой выборке. Метрика F1-мера по классификатору DummyClassifier показала крайне низкий результат 0.35, что говорит об адекватности подобранной модели!<br>
# <br>
# 6. На тестовой выборке наилучшая модель машинного обучения "LGBMClassifier на upsampling One Hot Encoding" показала следующие результаты качества метрик:<br>
#  - F1-мера: 0.61
#  - Метрика качества AUC-ROC модели:  0.89<br>
#
# Метрика F1-мера на тестовой выборке получилась значительно выше 0.59, поэтому поставленная цель задачи достигнута.<br>
# <br>
#
# 7. Дополнительно проведено исследование важности признаков исследуемого датасета. Исследование показывает стойкую закономерность: чем старше клиент и чем больше у него открыто продуктов в банке, тем выше вероятность того, что клиент и дальше будет пользоваться услугами банка. Но стоит также отметит выводы исследовательского аналтиза данных. Совместно с менеджментом банка необходимо понять природу диспропорций в клиентской базе по клиентам с нулевым балансом на счете, так как их доля составляет 36.19% всей клиентской базы.
#
#    Возможно требуется проведение акционной работы в области перевода клиентской базы на зарплатные проекты, тогда и характер распределения данных станет более нормализованным, а доля лояльных клиентов банка станет существенно выше.

# %%
fit_time = time.time() - start_all
print("Время на обработку всего проекта составило: ", round(fit_time/60,1), "мин")
# Out:
# Время на обработку всего проекта составило:  3.8 мин
